# %% [markdown]
# <a href="https://colab.research.google.com/github/maykonryan7/tecnicasdeprograma-o/blob/main/Eng_soft_6nov_Maykon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 Operadores

# %%
2**3
# Out:
# 8

# %%
 23/7
# Out:
# 3.2857142857142856

# %%
5+5*5/5
# Out:
# 10.0

# %%
4**(4//2)+7
# Out:
# 23

# %%
'''1 Faça um programa que leia dois números inteiros e exiba a soma deles'''
a=int(input("informe o numero:"))
b=int(input("informe o numero:"))
print(a+b)
# Out:
# informe o numero:10
# informe o numero:10
# 20

# %%
'''2 Faça um programa que leia a nota que um aluno tirou em P1(Prova 1) e P2(Prova 2).
Calcule a média aritmética.1Exiba esse resultado na tela'''
nota1=int(input("informe a nota do primeiro aluno:"))
nota2=int(input("informe a nota do segundo aluno:"))
media=(nota1+nota2)/2
print(media)

# %%
'''3Leia um nome armazenado em uma variável e imprima: Olá, nome_pessoa! (nome_pessoa é a variável)'''
nome="maykon"
print(f"ola, {nome}!")
# Out:
# ola, maykon!

# %%
'''4Solicite que o usuário digite seu nome.Solicite que o usuários digite seu ano de nascimento (formato AAAA). Exiba na tela: nome_usuario nasceu em ano_nascimento! (nome_usuario e ano_nascimento são as variáveis)'''
nome_usuario = input("Digite seu nome: ")
ano_nascimento = input("Digite seu ano de nascimento (AAAA): ")
print(nome_usuario + " nasceu em " + ano_nascimento + "!")
# Out:
# Digite seu nome: maykon
# Digite seu ano de nascimento (AAAA): 2005
# maykon nasceu em 2005!

# %%
'''5solicite que o usuário digite seu nome e sua idade.Imprima “Olá, nome! Você tem idade anos?” Imprima o ano de nascimento da pessoa (ignore meses e dias0
Imprima o nome da pessoa idade vezes (João tem 18, imprime JoãoJoão...)'''
nome=input("digite seu nome")
idade= int(input("digite sua idade"))
print("ola,", nome + "!voce tem", idade, "anos?")

ano_atual = 2025
ano_nascimento = ano_atual - idade
print("voce nasceu em", ano_nascimento)

print(nome * idade)
# Out:
# digite seu nomemaykon
# digite sua idade20
# ola, maykon!voce tem 20 anos?
# voce nasceu em 2005
# maykonmaykonmaykonmaykonmaykonmaykonmaykonmaykonmaykonmaykonmaykonmaykonmaykonmaykonmaykonmaykonmaykonmaykonmaykonmaykon

# %%
'''6Solicite ao usuário que digite três notas depois calcule e exiba a média ponderada'''

nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
media = (nota1 + nota2 + nota3) / 3
print("A média é:", media)
# Out:
# Digite a primeira nota: 5
# Digite a segunda nota: 6
# Digite a terceira nota: 4
# A média é: 5.0

# %%
'''7Solicite ao usuário três notas e seus respectivos pesos, depois calcule e exiba a média ponderada.'''
nota1 = float(input("Digite a primeira nota: "))
peso1 = float(input("Digite o peso da primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
peso2 = float(input("Digite o peso da segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
peso3 = float(input("Digite o peso da terceira nota: "))

media_ponderada = (nota1 * peso1 + nota2 * peso2 + nota3 * peso3) / (peso1 + peso2 + peso3)
print("A média ponderada é:", media_ponderada)
# Out:
# Digite a primeira nota: 5
# Digite o peso da primeira nota: 6
# Digite a segunda nota: 3
# Digite o peso da segunda nota: 5
# Digite a terceira nota: 5
# Digite o peso da terceira nota: 6
# A média ponderada é: 4.411764705882353

# %%
''' 8 Peça ao usuário um número e exiba a soma de seus dígitos.'''
numero = input("Digite um número: ")
soma = 0
for digito in numero:
    soma += int(digito)
print("A soma dos dígitos é:", soma)
# Out:
# Digite um número: 12
# A soma dos dígitos é: 3

# %%
'''9 Peça ao usuário uma palavra e exiba-a invertida sem usar laços.'''
palavra = input("Digite uma palavra: ")
palavra_invertida = palavra[::-1]
print("Palavra invertida:", palavra_invertida)
# Out:
# Digite uma palavra: maykon
# Palavra invertida: nokyam
